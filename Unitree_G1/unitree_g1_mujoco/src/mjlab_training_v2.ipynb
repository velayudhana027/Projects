# %%
#install uv package manager
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.cargo/bin"

# Clone mjlab and install
# !git clone https://github.com/mujocolab/mjlab.git
# %cd mjlab
# !uv sync
# 1. Mount Drive first
from google.colab import drive
drive.mount('/content/drive')

# 2. Start training
# !uv run train Mjlab-Velocity-Flat-Unitree-G1 --env.scene.num-envs 4096
# Out:
# Streaming output truncated to the last 5000 lines.
#                         Collection time: 1.397s
#                           Learning time: 0.132s
#                         Mean value loss: 0.0247
#                     Mean surrogate loss: -0.0144
#                       Mean entropy loss: 12.2333
#                             Mean reward: 51.51
#                     Mean episode length: 1000.00
#                         Mean action std: 0.41
#    Episode_Reward/track_linear_velocity: 1.4749
#   Episode_Reward/track_angular_velocity: 0.7207
#                  Episode_Reward/upright: 0.9761
#                     Episode_Reward/pose: 0.6310
#             Episode_Reward/body_ang_vel: -0.0244
#         Episode_Reward/angular_momentum: -0.0348
#           Episode_Reward/dof_pos_limits: -0.0044
#           Episode_Reward/action_rate_l2: -0.9790
#                 Episode_Reward/air_time: 0.0000
#           Episode_Reward/foot_clearance: -0.1340
# ...

# %%
# Create a destination folder in your Drive
# !mkdir -p /content/drive/MyDrive/mjlab_final_results

# Copy everything from the Colab local disk to your permanent Drive
# !cp -r /content/mjlab/mjlab/mjlab/mjlab/logs /content/drive/MyDrive/mjlab_final_results/

# %%
# 1. Install headless display dependencies
# !apt-get update && apt-get install -y libgl1-mesa-glx libosmesa6

# 2. Set environment variables so MuJoCo knows to use OSMesa (software rendering)
import os
os.environ['MUJOCO_GL'] = 'osmesa'
os.environ['PYOPENGL_PLATFORM'] = 'osmesa'

# !uv run play Mjlab-Velocity-Flat-Unitree-G1 --help
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,613 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,120 kB]
# ...

# %%
# Define the base path for your training run
BASE_PATH="/content/mjlab/mjlab/mjlab/mjlab/logs/rsl_rl/g1_velocity/2026-03-09_21-42-00"

## 1. Early Model (0)
#!timeout 60s uv run play Mjlab-Velocity-Flat-Unitree-G1 \
#  --checkpoint-file /content/mjlab/mjlab/mjlab/mjlab/logs/rsl_rl/g1_velocity/2026-03-09_21-42-00/model_0.pt \
#  --video True \
#  --video-length 100
## 2. Early Model (5k)
#!timeout 60s uv run play Mjlab-Velocity-Flat-Unitree-G1 \
#  --checkpoint-file /content/mjlab/mjlab/mjlab/mjlab/logs/rsl_rl/g1_velocity/2026-03-09_21-42-00/model_5000.pt \
#  --video True \
#  --video-length 100

## 3. Intermediate Model (15k)
#!timeout 60s uv run play Mjlab-Velocity-Flat-Unitree-G1 \
#  --checkpoint-file /content/mjlab/mjlab/mjlab/mjlab/logs/rsl_rl/g1_velocity/2026-03-09_21-42-00/model_15000.pt \
#  --video True \
#  --video-length 100

## 4. Refined Model (25k)
#!timeout 60s uv run play Mjlab-Velocity-Flat-Unitree-G1 \
#  --checkpoint-file /content/mjlab/mjlab/mjlab/mjlab/logs/rsl_rl/g1_velocity/2026-03-09_21-42-00/model_25000.pt \
#  --video True \
#  --video-length 100

# 5. Early Model (29k)
# !timeout 60s uv run play Mjlab-Velocity-Flat-Unitree-G1 \
  --checkpoint-file /content/mjlab/mjlab/mjlab/mjlab/logs/rsl_rl/g1_velocity/2026-03-09_21-42-00/model_29000.pt \
  --video True \
  --video-length 100
# Out:
# [INFO]: Loading checkpoint: model_29000.pt
# Warp 1.12.0 initialized:
#    CUDA Toolkit 12.9, Driver 13.0
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA A100-SXM4-40GB" (39 GiB, sm_80, mempool enabled)
#    Kernel cache:
#      /root/.cache/warp/1.12.0
# Warp DeprecationWarning: The symbol `warp.context.runtime` will soon be removed from the public API. It can still be accessed from `warp._src.context.runtime` but might be changed or removed without notice.
# Module mujoco_warp._src.smooth 75c1b76 load on device 'cuda:0' took 3.82 ms  (cached)
# Module mujoco_warp._src.collision_driver 4d8b905 load on device 'cuda:0' took 0.52 ms  (cached)
# Module _nxn_broadphase__locals__kernel_e916423b e916423 load on device 'cuda:0' took 0.55 ms  (cached)
# Module _primitive_narrowphase__locals__primitive_narrowphase_f33437d9 f33437d load on device 'cuda:0' took 0.84 ms  (cached)
# Module mujoco_warp._src.constraint e4fb920 load on device 'cuda:0' took 2.81 ms  (cached)
# ...

# %%
# !uv run train Mjlab-Velocity-Rough-Unitree-G1 --help
# Out:
# usage: /content/mjlab/mjlab/mjlab/mjlab/.venv/bin/train Mjlab-Velocity-Rough-Unitree-G1 [-h] [OPTIONS]
#
# ╭─ options ────────────────────────────────────────────────────────────────────╮
# │ -h, --help                                                                   │
# │       show this help message and exit                                        │
# │ --registry-name {None}|STR                                                   │
# │       (default: None)                                                        │
# │ --video {True,False}                                                         │
# │       (default: False)                                                       │
# │ --video-length INT                                                           │
# │       (default: 200)                                                         │
# │ --video-interval INT                                                         │
# ...

# %%
import torch

# 1. Path to your fix-model
checkpoint_path = "/content/mjlab/mjlab/mjlab/mjlab/logs/rsl_rl/g1_velocity/2026-03-09_21-42-00/model_29999_final_fix.pt"
checkpoint = torch.load(checkpoint_path)

# 2. REMOVE the optimizer state
# This forces the training script to create a new optimizer with the correct 286/298 shapes.
if 'optimizer_state_dict' in checkpoint:
    del checkpoint['optimizer_state_dict']
    print("Old optimizer state removed.")

# 3. Save as the "Clean" version
clean_path = "/content/mjlab/mjlab/mjlab/mjlab/logs/rsl_rl/g1_velocity/2026-03-09_21-42-00/model_29999_rough_clean.pt"
torch.save(checkpoint, clean_path)
print(f"Success! Cleaned model saved to: {clean_path}")
# Out:
# Old optimizer state removed.
# Success! Cleaned model saved to: /content/mjlab/mjlab/mjlab/mjlab/logs/rsl_rl/g1_velocity/2026-03-09_21-42-00/model_29999_rough_clean.pt

# %%
# !uv run train Mjlab-Velocity-Rough-Unitree-G1 \
  --agent.resume True \
  --agent.load-run 2026-03-09_21-42-00 \
  --agent.load-checkpoint model_29999_rough_clean.pt \
  --agent.logger wandb \
  --agent.wandb-project "G1_Phase2_Hardening" \
  --env.scene.num-envs 4096
# Out:
# [INFO] Training with: device=cuda:0, seed=42, rank=0
# [INFO] Logging experiment in directory: logs/rsl_rl/g1_velocity/2026-03-10_15-41-43
# Setting seed: 42
# Warp 1.12.0 initialized:
#    CUDA Toolkit 12.9, Driver 13.0
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA A100-SXM4-40GB" (39 GiB, sm_80, mempool enabled)
#    Kernel cache:
#      /root/.cache/warp/1.12.0
# Curriculum terrain generation took 0.4369 seconds.
# Warp DeprecationWarning: The symbol `warp.context.runtime` will soon be removed from the public API. It can still be accessed from `warp._src.context.runtime` but might be changed or removed without notice.
# Module mujoco_warp._src.smooth 75c1b76 load on device 'cuda:0' took 3.97 ms  (cached)
# Module mujoco_warp._src.collision_driver 4d8b905 load on device 'cuda:0' took 0.53 ms  (cached)
# Module _nxn_broadphase__locals__kernel_e916423b e916423 load on device 'cuda:0' took 0.55 ms  (cached)
# ...

# %%
#install uv package manager
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.cargo/bin"

# Clone mjlab and install
# !git clone https://github.com/mujocolab/mjlab.git
# %cd mjlab
# !uv sync
# 1. Mount Drive first
from google.colab import drive
drive.mount('/content/drive')
# Out:
# downloading uv 0.10.9 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!
# Cloning into 'mjlab'...
# remote: Enumerating objects: 12094, done.
# remote: Counting objects: 100% (4127/4127), done.
# remote: Compressing objects: 100% (726/726), done.
# remote: Total 12094 (delta 3803), reused 3478 (delta 3388), pack-reused 7967 (from 3)
# Receiving objects: 100% (12094/12094), 47.35 MiB | 18.77 MiB/s, done.
# Resolving deltas: 100% (7902/7902), done.
# /content/mjlab
# Using CPython 3.13.12
# Creating virtual environment at: .venv
# Resolved 211 packages in 1ms
# Prepared 159 packages in 1m 38s
# Installed 159 packages in 1.81s
#  + absl-py==2.3.1
#  + annotated-types==0.7.0
#  + anyio==4.11.0
#  + asttokens==3.0.0
#  + attrs==25.4.0
#  + bcrypt==5.0.0
#  + certifi==2025.10.5
#  + cffi==2.0.0
#  + cfgv==3.4.0
#  + charset-normalizer==3.4.4
#  + click==8.3.0
#  + cloudpickle==3.1.1
#  + colorlog==6.10.1
# ...

# %%
# !uv run train Mjlab-Velocity-Rough-Unitree-G1 \
  --agent.resume False \
  --agent.load-checkpoint /content/drive/MyDrive/mjlab_final_results/refined\ models/model_29999_rough_clean.pt \
  --agent.logger wandb \
  --agent.wandb-project "G1_Phase2_T4" \
  --env.scene.num-envs 2048
# Out:
# error: Failed to spawn: `train`
#   Caused by: No such file or directory (os error 2)
